# %%
import pandas as pd

# %%
data = pd.read_json('petiteknit.json')

# %%
data
# Out:
#                                                name        language  \
# 0      Sunday Sweater - Mohair Edition – PetiteKnit          dansk.
# 1                    Hanstholm Sweater – PetiteKnit          dansk.
# 2   Ankers Trøje - My Boyfriend's Size – PetiteKnit          dansk.
# 3                           Ankers Hue – PetiteKnit       herunder.
# 4                     Vesterhavssættet – PetiteKnit   halstørklæde.
# 5                             Ingeborg – PetiteKnit          dansk.
# 6                            Baggy Hue – PetiteKnit          dansk.
# 7             Annas Cardigan - My Size – PetiteKnit          dansk.
# 8               Ankers Trøje - My Size – PetiteKnit          dansk.
# 9              Klassisk Smock Cardigan – PetiteKnit  knappestolper.
# 10                      Balloncardigan – PetiteKnit          dansk.
# 11                         Hipsterhuen – PetiteKnit          dansk.
# 12           Oslohuen - mohair edition – PetiteKnit          dansk.
# ...
